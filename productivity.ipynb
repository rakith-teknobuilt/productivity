# %%
import numpy as np
import pandas as pd

# %%
iwp = pd.read_csv('pace_workmanagement_iwp_summary.csv')
cwp = pd.read_csv('pace_workmanagement_cwp_summary.csv')
dp = pd.read_csv('pace_workmanagement_iwp_daily_progress_monitoring.csv')
# Out:
# C:\Users\OKKKK\AppData\Local\Temp\ipykernel_13208\2121558928.py:1: DtypeWarning: Columns (7,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   iwp = pd.read_csv('pace_workmanagement_iwp_summary.csv')

# %%
cwp
# Out:
#         id  user_id cwa_id  discipline_id  projectId  phaseId  cwpUnit  \
# 0     1592      166     \N             97          1        3      174
# 1     1593        1     \N             97          1        3      174
# 2     1594        1     \N              5          1        3      174
# 3     1595        1     \N              5          1        3      174
# 4     1596        1     \N              5          1        2      151
# ...    ...      ...    ...            ...        ...      ...      ...
# 1880  4192      200     \N            384         54        2      179
# 1881  4193      200     \N            384         54        6      187
# 1882  4194      200     \N            384         54        3      181
# 1883  4195      200     \N            384         54       11      214
# 1884  4196      200     \N            399         54       10      210
#
#       ewpRefId                      ewpRefNo  \
# 0            0           EW-A12-1X11-B-FI-CV
# 1         1812           EW-A11-1X11-C-FI-CV
# 2         1813           EW-A12-1X11-D-FI-PI
# 3         1814           EW-A11-1X11-E-FI-PI
# 4         1872    EW-A01-WP2.2-010-GN-MC-300
# ...        ...                           ...
# 1880      3975  EWP-A02-WP2.10-999-FI-LC-101
# 1881      3976  EWP-A05-WP4.11-999-FI-LC-101
# 1882      3977   EWP-A11-WP8.1-999-FI-LC-101
# 1883      3978   EWP-Z02-WP0.0-999-FI-LC-101
# 1884      3979   EWP-C09-WP6.2-000-FI-MC-102
#
#                                                  cwa  ...    contractorDcn  \
# 0                                                A12  ...               \N
# 1                                                A11  ...               \N
# 2                                                A12  ...               \N
# 3                                                A11  ...               \N
# 4                                      A01-WP2.2-010  ...               \N
# ...                                              ...  ...              ...
# 1880                               CLU - Common Area  ...  LG00-ZX-E-71649
# 1881                 Common Area Utility Systems -AG  ...  LG00-ZX-E-71647
# 1882  Additional Condensate Handling Facilities - AG  ...  LG00-ZX-E-71650
# 1883                        BF - Overall Common Area  ...               \N
# 1884                LNG Loading Facilities (topside)  ...               \N
#
#      revisionDescription blockchainWorkBlockId blockchain_status linked_area  \
# 0                     \N                    \N                \N          \N
# 1                     \N                    \N                \N          \N
# 2                     \N                    \N                \N          \N
# 3                     \N                    \N                \N          \N
# 4                     \N                    \N                \N          \N
# ...                  ...                   ...               ...         ...
# 1880                  \N                    \N                \N          \N
# 1881                  \N                    \N                \N          \N
# 1882                  \N                    \N                \N          \N
# 1883                  \N                    \N                \N          \N
# 1884                  \N                    \N                \N          \N
#
#      reject_remark pc_ForecastComplete_Quaterly  \
# 0               \N                   0000-00-00
# 1               \N                   0000-00-00
# 2               \N                   0000-00-00
# 3               \N                   0000-00-00
# 4               \N                   0000-00-00
# ...            ...                          ...
# 1880            \N                   0000-00-00
# 1881            \N                   0000-00-00
# 1882            \N                   0000-00-00
# 1883            \N                   0000-00-00
# 1884            \N                   0000-00-00
#
#       pc_ForecastStart_Quaterly_Exe pc_ForecastFinish_Quaterly_Exe  \
# 0                        0000-00-00                     0000-00-00
# 1                        0000-00-00                     0000-00-00
# 2                        0000-00-00                     0000-00-00
# 3                        0000-00-00                     0000-00-00
# 4                        0000-00-00                     0000-00-00
# ...                             ...                            ...
# 1880                     0000-00-00                     0000-00-00
# 1881                     0000-00-00                     0000-00-00
# 1882                     0000-00-00                     0000-00-00
# 1883                     0000-00-00                     0000-00-00
# 1884                     0000-00-00                     0000-00-00
#
#      releaseBlockchainStatus
# 0                         \N
# 1                         \N
# 2                         \N
# 3                         \N
# 4                         \N
# ...                      ...
# 1880                      \N
# 1881                      \N
# 1882                      \N
# 1883                      \N
# 1884                      \N
#
# [1885 rows x 96 columns]

# %%
dp
# Out:
#        dailyProgressId  iwpId  checklistId  projectId  phaseId  iwpUnit  \
# 0                    1     99          126         51        1      152
# 1                    2     99          126         51        1      152
# 2                    3     99          126         51        1      152
# 3                    4     99          127         51        1      152
# 4                    5      6          126         51        1      152
# ...                ...    ...          ...        ...      ...      ...
# 12945            13464  18975          574         54        7      189
# 12946            13465  18975          574         54        7      189
# 12947            13466  18975          574         54        7      189
# 12948            13467  18975          574         54        7      189
# 12949            13468  18975          574         54        7      189
#
#        user_id  discipline_id iwpPstartDate iwpPfinishedDate  ...  \
# 0            1            353    2019-09-10       2019-09-11  ...
# 1            1            353    2019-09-10       2019-09-11  ...
# 2            1            353    2019-09-10       2019-09-11  ...
# 3            1            353    2019-09-12       2019-09-12  ...
# 4            1            353    2019-09-26       2019-09-28  ...
# ...        ...            ...           ...              ...  ...
# 12945      413            394    2024-03-16       2024-03-16  ...
# 12946      413            394    2024-03-20       2024-03-20  ...
# 12947      413            394    2024-03-25       2024-03-25  ...
# 12948      413            394    2024-03-27       2024-03-27  ...
# 12949      413            394    2024-03-28       2024-03-28  ...
#
#       iwpProgressDate             postDate  startGeoLocation  endGeoLocation  \
# 0          2019-09-10  2019-09-12 11:00:20                \N              \N
# 1          2019-09-11  2019-09-12 11:01:04                \N              \N
# 2          2019-09-12  2019-09-12 11:01:41                \N              \N
# 3          2019-09-12  2019-09-12 11:01:41                \N              \N
# 4          2019-09-26  2019-10-07 04:49:09                \N              \N
# ...               ...                  ...               ...             ...
# 12945      2024-03-16  2024-07-29 22:41:03                \N              \N
# 12946      2024-03-20  2024-07-29 22:41:56                \N              \N
# 12947      2024-03-25  2024-07-29 22:42:45                \N              \N
# 12948      2024-03-27  2024-07-29 22:48:11                \N              \N
# 12949      2024-03-28  2024-07-29 22:48:59                \N              \N
#
#       constructionHeight iwpflag iwpFinishTime iwpStartTime updateDate  \
# 0                     \N      \N            \N           \N         \N
# 1                     \N      \N            \N           \N         \N
# 2                     \N      \N            \N           \N         \N
# 3                     \N      \N            \N           \N         \N
# 4                     \N      \N            \N           \N         \N
# ...                  ...     ...           ...          ...        ...
# 12945                 \N      \N            \N           \N         \N
# 12946                 \N      \N            \N           \N         \N
# 12947                 \N      \N            \N           \N         \N
# 12948                 \N      \N            \N           \N         \N
# 12949                 \N      \N            \N           \N         \N
#
#       sub_discipline_id
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 12945                 0
# 12946                 0
# 12947                 0
# 12948                 0
# 12949                 0
#
# [12950 rows x 25 columns]

# %%
dp.columns
# Out:
# Index(['dailyProgressId', 'iwpId', 'checklistId', 'projectId', 'phaseId',
#        'iwpUnit', 'user_id', 'discipline_id', 'iwpPstartDate',
#        'iwpPfinishedDate', 'iwpTotalQuantity', 'iwpUom', 'iwpToDoQuantity',
#        'iwpDoneQuantity', 'iwpDonePercentage', 'iwpProgressDate', 'postDate',
#        'startGeoLocation', 'endGeoLocation', 'constructionHeight', 'iwpflag',
#        'iwpFinishTime', 'iwpStartTime', 'updateDate', 'sub_discipline_id'],
#       dtype='object')

# %%
iwp
# Out:
#           id  user_id  discipline_id  subDisciplineId  projectId  phaseId  \
# 0          1        1             97                0          1        1
# 1          4        1              5                0          1        1
# 2          5        1            353                0         51        1
# 3          6        1            353                0         51        1
# 4          7        1            353                0         51        1
# ...      ...      ...            ...              ...        ...      ...
# 11908  19119      235            384              339         54        1
# 11909  19120      235            384              339         54        1
# 11910  19121      235            384              339         54        1
# 11911  19122      235            384              338         54        1
# 11912  19123      235            384              338         54        1
#
#        iwpUnit cwpRefId                     cwpRefNo                   cwa  \
# 0          148        0                           \N                   B20
# 1          148        0           CW-B20-112-J-PR-PI                   B20
# 2          152        3   CW-A01-WP2.2-010-FI-LC-101         A01-WP2.2-010
# 3          152        4   CW-A01-WP2.2-010-FI-LC-102         A01-WP2.2-010
# 4          152       20   CW-A01-WP2.2-020-FI-LC-101         A01-WP2.2-020
# ...        ...      ...                          ...                   ...
# 11908      177     1749  CWP-A01-WP2.2-020-FI-LC-104  Acid Gas Removal-020
# 11909      177     1749  CWP-A01-WP2.2-020-FI-LC-104  Acid Gas Removal-020
# 11910      177     1749  CWP-A01-WP2.2-020-FI-LC-104  Acid Gas Removal-020
# 11911      177     1717  CWP-A01-WP2.6-000-UG-LC-101         A01-WP2.6-000
# 11912      177     1717  CWP-A01-WP2.6-000-UG-LC-101         A01-WP2.6-000
#
#        ... iwpPlannedCompleteExe iwpForecastCompleteExe iwpActualCompleteExe  \
# 0      ...                    \N                     \N                   \N
# 1      ...                    \N                     \N                   \N
# 2      ...                    \N                     \N                   \N
# 3      ...                    \N                     \N                   \N
# 4      ...                    \N                     \N                   \N
# ...    ...                   ...                    ...                  ...
# 11908  ...            0000-00-00             2024-04-18           0000-00-00
# 11909  ...            0000-00-00             2024-04-25           0000-00-00
# 11910  ...            0000-00-00             2024-05-18           0000-00-00
# 11911  ...            0000-00-00             2024-05-04           0000-00-00
# 11912  ...            0000-00-00             2024-05-04           0000-00-00
#
#        iwpPlannedHourExe iwpForecastHourExe iwpActualHourExe  \
# 0                     \N                 \N               \N
# 1                     \N                 \N               \N
# 2                     \N                 \N               \N
# 3                     \N                 \N               \N
# 4                     \N                 \N               \N
# ...                  ...                ...              ...
# 11908                  3                  3                0
# 11909                131                131                0
# 11910                103                103                0
# 11911                 16                 16                0
# 11912                 16                 16                0
#
#       blockchainWorkBlockId blockchain_status reject_remark  \
# 0                        \N                \N            \N
# 1                        \N                \N            \N
# 2                        \N                \N            \N
# 3                        \N                \N            \N
# 4                        \N                \N            \N
# ...                     ...               ...           ...
# 11908                    \N                \N            \N
# 11909                    \N                \N            \N
# 11910                    \N                \N            \N
# 11911                    \N                \N            \N
# 11912                    \N                \N            \N
#
#       releaseBlockchainStatus
# 0                          \N
# 1                          \N
# 2                          \N
# 3                          \N
# 4                          \N
# ...                       ...
# 11908                      \N
# 11909                      \N
# 11910                      \N
# 11911                      \N
# 11912                      \N
#
# [11913 rows x 97 columns]

# %%
iwp.columns
# Out:
# Index(['id', 'user_id', 'discipline_id', 'subDisciplineId', 'projectId',
#        'phaseId', 'iwpUnit', 'cwpRefId', 'cwpRefNo', 'cwa', 'cwpSubArea',
#        'cwpLevel', 'cwpType', 'iwpType', 'iwpNo', 'iwpRevision',
#        'revisionDescription', 'iwpDocumentContNo', 'iwpTitle',
#        'iwpDescription', 'iwpContractor', 'iwpForeman', 'iwpPlannedStartDate',
#        'iwpPlannedComplete', 'iwpPlannedHours', 'iwpForecastStartDate',
#        'iwpForecastComplete', 'iwpForecastHours', 'iwpActualStartDate',
#        'iwpActualComplete', 'iwpActualHours', 'in_schedule', 'current_status',
#        'status', 'addDate', 'my_selection', 'my_packages', 'import',
#        'iwpDefectFree', 'nonConformance', 'barcode', 'barcode_image',
#        'iwpActualCompleteTime', 'delayDuration', 'iwpPlannedStartTime',
#        'iwpForecastStartTime', 'iwpActualStartTime', 'iwpPlannedCompleteTime',
#        'iwpForecastCompleteTime', 'releaseLead', 'releaseLeadDate',
#        'releaseLeadRemarks', 'releaseEngMgr', 'releaseEngMgrDate',
#        'releaseEngMgrRemarks', 'iwpManager', 'iwpLead', 'releaseConstMgr',
#        'releaseConstMgrDate', 'releaseConstMgrRemarks',
#        'releaseConstMgrApprovalStatus', 'releaseHold', 'iwpReleaseHold',
#        'iwpReleaseRisks', 'iwpReleaseMitigationPlan', 'iwpReleaseStatus',
#        'contractorId', 'contractorDcn', 'iwpSupervisor',
#        'releaseConsSupApprovalStatus', 'releaseConsSup', 'releaseConsSupDate',
#        'releaseConsSupRemarks', 'key_item_total_quantity', 'key_item_uom',
#        'key_item_id', 'manualorSystem', 'construction_manager_id',
#        'supervisor_id', 'compiledBIyId', 'checkedByd', 'approvedById',
#        'iwpActivityId', 'iwpKeyQuantity', 'iwpPlannedStartDateExe',
#        'iwpForecastStartDateExe', 'iwpActualStartDateExe',
#        'iwpPlannedCompleteExe', 'iwpForecastCompleteExe',
#        'iwpActualCompleteExe', 'iwpPlannedHourExe', 'iwpForecastHourExe',
#        'iwpActualHourExe', 'blockchainWorkBlockId', 'blockchain_status',
#        'reject_remark', 'releaseBlockchainStatus'],
#       dtype='object')

# %%
iwp.describe()
# Out:
#                  id       user_id  discipline_id  subDisciplineId  \
# count  11913.000000  11913.000000   11913.000000     11913.000000
# mean   11867.991774    229.546462     386.199950       351.610929
# std     4893.883206    133.631387      43.800039        64.099919
# min        1.000000      1.000000       3.000000         0.000000
# 25%     7816.000000    215.000000     388.000000       344.000000
# 50%    12668.000000    235.000000     394.000000       344.000000
# 75%    15950.000000    281.000000     394.000000       388.000000
# max    19123.000000    413.000000     433.000000       434.000000
#
#           projectId       phaseId       iwpUnit       iwpType  \
# count  11913.000000  11913.000000  11913.000000  11913.000000
# mean      52.905817      2.422983    179.675145      1.002015
# std        7.448290      1.995958      5.559925      0.063447
# min        1.000000      1.000000    148.000000      1.000000
# 25%       54.000000      1.000000    177.000000      1.000000
# 50%       54.000000      2.000000    179.000000      1.000000
# 75%       54.000000      3.000000    181.000000      1.000000
# max       54.000000     12.000000    216.000000      5.000000
#
#        iwpForecastHours        status       addDate  my_selection  \
# count      1.191300e+04  11913.000000  1.191300e+04  11913.000000
# mean       2.806540e+09     27.940905  1.692392e+09      0.000672
# std        3.063238e+11      4.441380  2.381764e+07      0.025906
# min        0.000000e+00      0.000000  1.565961e+09      0.000000
# 25%        0.000000e+00     27.000000  1.670304e+09      0.000000
# 50%        0.000000e+00     28.000000  1.697633e+09      0.000000
# 75%        7.000000e+01     31.000000  1.712054e+09      0.000000
# max        3.343423e+13     32.000000  1.722274e+09      1.000000
#
#         my_packages        import  iwpDefectFree  nonConformance  \
# count  11913.000000  11913.000000   11913.000000         11913.0
# mean       0.598422      0.848821       0.000084             0.0
# std        0.490238      0.358239       0.009162             0.0
# min        0.000000      0.000000       0.000000             0.0
# 25%        0.000000      1.000000       0.000000             0.0
# 50%        1.000000      1.000000       0.000000             0.0
# 75%        1.000000      1.000000       0.000000             0.0
# max        1.000000      1.000000       1.000000             0.0
#
#        iwpReleaseStatus  manualorSystem
# count      11913.000000    11913.000000
# mean           1.960295        0.286158
# std            1.391782        0.451983
# min            1.000000        0.000000
# 25%            1.000000        0.000000
# 50%            1.000000        0.000000
# 75%            4.000000        1.000000
# max            4.000000        1.000000

# %%
iwp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11913 entries, 0 to 11912
# Data columns (total 97 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             11913 non-null  int64
#  1   user_id                        11913 non-null  int64
#  2   discipline_id                  11913 non-null  int64
#  3   subDisciplineId                11913 non-null  int64
#  4   projectId                      11913 non-null  int64
#  5   phaseId                        11913 non-null  int64
#  6   iwpUnit                        11913 non-null  int64
#  7   cwpRefId                       11913 non-null  object
#  8   cwpRefNo                       11913 non-null  object
#  9   cwa                            11913 non-null  object
#  10  cwpSubArea                     11890 non-null  object
#  11  cwpLevel                       11891 non-null  object
#  12  cwpType                        11889 non-null  object
#  13  iwpType                        11913 non-null  int64
#  14  iwpNo                          11913 non-null  object
#  15  iwpRevision                    11913 non-null  object
#  16  revisionDescription            11581 non-null  object
#  17  iwpDocumentContNo              6690 non-null   object
#  18  iwpTitle                       11913 non-null  object
#  19  iwpDescription                 11913 non-null  object
#  20  iwpContractor                  11462 non-null  object
#  21  iwpForeman                     11801 non-null  object
#  22  iwpPlannedStartDate            11913 non-null  object
#  23  iwpPlannedComplete             11913 non-null  object
#  24  iwpPlannedHours                11913 non-null  object
#  25  iwpForecastStartDate           11913 non-null  object
#  26  iwpForecastComplete            11913 non-null  object
#  27  iwpForecastHours               11913 non-null  float64
#  28  iwpActualStartDate             11913 non-null  object
#  29  iwpActualComplete              11913 non-null  object
#  30  iwpActualHours                 11913 non-null  object
#  31  in_schedule                    10112 non-null  object
#  32  current_status                 11913 non-null  object
#  33  status                         11913 non-null  int64
#  34  addDate                        11913 non-null  int64
#  35  my_selection                   11913 non-null  int64
#  36  my_packages                    11913 non-null  int64
#  37  import                         11913 non-null  int64
#  38  iwpDefectFree                  11913 non-null  int64
#  39  nonConformance                 11913 non-null  int64
#  40  barcode                        11913 non-null  object
#  41  barcode_image                  11913 non-null  object
#  42  iwpActualCompleteTime          4535 non-null   object
#  43  delayDuration                  11913 non-null  object
#  44  iwpPlannedStartTime            4538 non-null   object
#  45  iwpForecastStartTime           4536 non-null   object
#  46  iwpActualStartTime             4536 non-null   object
#  47  iwpPlannedCompleteTime         4538 non-null   object
#  48  iwpForecastCompleteTime        4536 non-null   object
#  49  releaseLead                    11913 non-null  object
#  50  releaseLeadDate                11913 non-null  object
#  51  releaseLeadRemarks             9897 non-null   object
#  52  releaseEngMgr                  11913 non-null  object
#  53  releaseEngMgrDate              11913 non-null  object
#  54  releaseEngMgrRemarks           11913 non-null  object
#  55  iwpManager                     11913 non-null  object
#  56  iwpLead                        11913 non-null  object
#  57  releaseConstMgr                11913 non-null  object
#  58  releaseConstMgrDate            11913 non-null  object
#  59  releaseConstMgrRemarks         11901 non-null  object
#  60  releaseConstMgrApprovalStatus  11913 non-null  object
#  61  releaseHold                    11913 non-null  object
#  62  iwpReleaseHold                 8024 non-null   object
#  63  iwpReleaseRisks                8024 non-null   object
#  64  iwpReleaseMitigationPlan       8024 non-null   object
#  65  iwpReleaseStatus               11913 non-null  int64
#  66  contractorId                   11913 non-null  object
#  67  contractorDcn                  11913 non-null  object
#  68  iwpSupervisor                  11629 non-null  object
#  69  releaseConsSupApprovalStatus   11913 non-null  object
#  70  releaseConsSup                 11913 non-null  object
#  71  releaseConsSupDate             11913 non-null  object
#  72  releaseConsSupRemarks          8126 non-null   object
#  73  key_item_total_quantity        11913 non-null  object
#  74  key_item_uom                   11913 non-null  object
#  75  key_item_id                    11913 non-null  object
#  76  manualorSystem                 11913 non-null  int64
#  77  construction_manager_id        11913 non-null  object
#  78  supervisor_id                  11913 non-null  object
#  79  compiledBIyId                  11913 non-null  object
#  80  checkedByd                     11913 non-null  object
#  81  approvedById                   11913 non-null  object
#  82  iwpActivityId                  11680 non-null  object
#  83  iwpKeyQuantity                 4644 non-null   object
#  84  iwpPlannedStartDateExe         11913 non-null  object
#  85  iwpForecastStartDateExe        11913 non-null  object
#  86  iwpActualStartDateExe          11913 non-null  object
#  87  iwpPlannedCompleteExe          11913 non-null  object
#  88  iwpForecastCompleteExe         11913 non-null  object
#  89  iwpActualCompleteExe           11913 non-null  object
#  90  iwpPlannedHourExe              11913 non-null  object
#  91  iwpForecastHourExe             11913 non-null  object
#  92  iwpActualHourExe               11913 non-null  object
#  93  blockchainWorkBlockId          11913 non-null  object
#  94  blockchain_status              11913 non-null  object
#  95  reject_remark                  11913 non-null  object
#  96  releaseBlockchainStatus        11913 non-null  object
# dtypes: float64(1), int64(17), object(79)
# memory usage: 8.8+ MB

# %%
iwp.iloc[:,15:31]
# Out:
#       iwpRevision     revisionDescription  \
# 0               0                      \N
# 1               0                      \N
# 2               0                      \N
# 3               0                      \N
# 4               0                      \N
# ...           ...                     ...
# 11908           1  Issued for Information
# 11909           1  Issued for Information
# 11910           1  Issued for Information
# 11911           1  Issued for Information
# 11912           1  Issued for Information
#
#                           iwpDocumentContNo  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 11908  IWP-A01-WP2.2-020-FI-LC-104-CV02-112
# 11909  IWP-A01-WP2.2-020-FI-LC-104-CV02-113
# 11910  IWP-A01-WP2.2-020-FI-LC-104-CV02-114
# 11911  IWP-A01-WP2.6-000-UG-LC-101-CV01-327
# 11912  IWP-A01-WP2.6-000-UG-LC-101-CV01-328
#
#                                                 iwpTitle  \
# 0      MAIN E/W PIPE RACK AREA - E-W PIPEWAY - Equipm...
# 1                                         Piperacks Work
# 2                                  Foundation & Backfill
# 3                                  Foundation & Backfill
# 4                    Foundation work for Steel Structure
# ...                                                  ...
# 11908  Concrete Work for Miscellaneous Platform Found...
# 11909  Concrete Work for Miscellaneous Platform Found...
# 11910  Concrete Work for Miscellaneous Platform Found...
# 11911          Excavation Works for Equipment Foundation
# 11912          Excavation Works for Equipment Foundation
#
#                                           iwpDescription  \
# 0      MAIN E/W PIPE RACK AREA - E-W PIPEWAY - Equipm...
# 1                                         Piperacks Work
# 2                                  Foundation & Backfill
# 3                                  Foundation & Backfill
# 4                    Foundation work for Steel Structure
# ...                                                  ...
# 11908  Concrete Work for Miscellaneous Platform Found...
# 11909  Concrete Work for Miscellaneous Platform Found...
# 11910  Concrete Work for Miscellaneous Platform Found...
# 11911  Excavation Works for Equipment Foundation (7-P...
# 11912  Excavation Works for Equipment Foundation (7-P...
#
#                            iwpContractor iwpForeman iwpPlannedStartDate  \
# 0                                    NaN        NaN          2019-10-15
# 1                                    NaN        NaN          2019-11-04
# 2                                    NaN        NaN          2019-10-15
# 3                                    NaN        NaN          2019-09-23
# 4                                    NaN        NaN          2021-06-01
# ...                                  ...        ...                 ...
# 11908  "[{\\"DECN\\":\\"2024-07-29\\"}]"         \N          2024-04-10
# 11909  "[{\\"DECN\\":\\"2024-07-29\\"}]"         \N          2024-04-12
# 11910  "[{\\"DECN\\":\\"2024-07-29\\"}]"         \N          2024-04-29
# 11911  "[{\\"DECN\\":\\"2024-07-29\\"}]"         \N          2024-04-25
# 11912  "[{\\"DECN\\":\\"2024-07-29\\"}]"         \N          2024-04-25
#
#       iwpPlannedComplete iwpPlannedHours iwpForecastStartDate  \
# 0             2019-10-30               0           2019-10-16
# 1             2019-11-09               0           2019-11-04
# 2             2019-10-30               0           2019-10-15
# 3             2019-10-08               0           2019-09-23
# 4             2021-06-10               0           2021-06-07
# ...                  ...             ...                  ...
# 11908         2024-04-11               3           2024-04-09
# 11909         2024-04-13             131           2024-04-10
# 11910         2024-04-30             103           2024-04-20
# 11911         2024-04-26              16           2024-04-25
# 11912         2024-04-26              16           2024-04-25
#
#       iwpForecastComplete  iwpForecastHours iwpActualStartDate  \
# 0                      \N               0.0                 \N
# 1              2019-11-09               0.0                 \N
# 2              2019-10-30               0.0                 \N
# 3              2019-10-08               0.0         2019-09-29
# 4                      \N               0.0                 \N
# ...                   ...               ...                ...
# 11908          2024-04-10               3.0         2024-04-09
# 11909          2024-04-11             131.0         2024-04-10
# 11910          2024-04-21             103.0         2024-04-20
# 11911          2024-04-26              16.0         2024-04-25
# 11912          2024-04-26              16.0         2024-04-25
#
#       iwpActualComplete iwpActualHours
# 0                    \N              0
# 1                    \N              0
# 2                    \N              0
# 3                    \N              0
# 4                    \N              0
# ...                 ...            ...
# 11908        2024-07-29              0
# 11909        2024-07-29              0
# 11910        2024-07-29              0
# 11911        2024-07-29              0
# 11912        0000-00-00              0
#
# [11913 rows x 16 columns]

# %%
iwpdate=iwp[['iwpPlannedStartDate',
       'iwpPlannedComplete','iwpForecastStartDate',
       'iwpForecastComplete', 'iwpActualStartDate',
       'iwpActualComplete']]

# %%
iwpdate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11913 entries, 0 to 11912
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   iwpPlannedStartDate   11913 non-null  object
#  1   iwpPlannedComplete    11913 non-null  object
#  2   iwpForecastStartDate  11913 non-null  object
#  3   iwpForecastComplete   11913 non-null  object
#  4   iwpActualStartDate    11913 non-null  object
#  5   iwpActualComplete     11913 non-null  object
# dtypes: object(6)
# memory usage: 558.6+ KB

# %%
# Convert 'date_column' to datetime, invalid parsing will be set as NaT
iwpdate['iwpPlannedStartDate'] = pd.to_datetime(iwpdate['iwpPlannedStartDate'], errors='coerce')
iwpdate['iwpPlannedComplete'] = pd.to_datetime(iwpdate['iwpPlannedComplete'], errors='coerce')
iwpdate['iwpForecastStartDate'] = pd.to_datetime(iwpdate['iwpForecastStartDate'], errors='coerce')
iwpdate['iwpForecastComplete'] = pd.to_datetime(iwpdate['iwpForecastComplete'], errors='coerce')
iwpdate['iwpActualStartDate'] = pd.to_datetime(iwpdate['iwpActualStartDate'], errors='coerce')
iwpdate['iwpActualComplete'] = pd.to_datetime(iwpdate['iwpActualComplete'], errors='coerce')

# Count the number of NaT values in 'date_column'
invalid_dates_count_iwpPlannedStartDate = iwpdate['iwpPlannedStartDate'].isna().sum()
invalid_dates_count_iwpPlannedComplete = iwpdate['iwpPlannedComplete'].isna().sum()
invalid_dates_count_iwpForecastStartDate = iwpdate['iwpForecastStartDate'].isna().sum()
invalid_dates_count_iwpForecastComplete = iwpdate['iwpForecastComplete'].isna().sum()
invalid_dates_count_iwpActualStartDate = iwpdate['iwpActualStartDate'].isna().sum()
invalid_dates_count_iwpActualComplete = iwpdate['iwpActualComplete'].isna().sum()

print("invalid_dates_count_iwpPlannedStartDate",invalid_dates_count_iwpPlannedStartDate)
print("invalid_dates_count_iwpPlannedComplete",invalid_dates_count_iwpPlannedComplete)
print("invalid_dates_count_iwpForecastStartDate",invalid_dates_count_iwpForecastStartDate)
print("invalid_dates_count_iwpForecastComplete",invalid_dates_count_iwpForecastComplete)
print("invalid_dates_count_iwpActualStartDate",invalid_dates_count_iwpActualStartDate)
print("invalid_dates_count_iwpActualComplete",invalid_dates_count_iwpActualComplete)
# Out:
# invalid_dates_count_iwpPlannedStartDate 4
# invalid_dates_count_iwpPlannedComplete 2
# invalid_dates_count_iwpForecastStartDate 1019
# invalid_dates_count_iwpForecastComplete 261
# invalid_dates_count_iwpActualStartDate 5860
# invalid_dates_count_iwpActualComplete 9347
# C:\Users\Ashik Kumar\AppData\Local\Temp\ipykernel_16276\1732533593.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iwpdate['iwpPlannedStartDate'] = pd.to_datetime(iwpdate['iwpPlannedStartDate'], errors='coerce')
# C:\Users\Ashik Kumar\AppData\Local\Temp\ipykernel_16276\1732533593.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iwpdate['iwpPlannedComplete'] = pd.to_datetime(iwpdate['iwpPlannedComplete'], errors='coerce')
# C:\Users\Ashik Kumar\AppData\Local\Temp\ipykernel_16276\1732533593.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iwpdate['iwpForecastStartDate'] = pd.to_datetime(iwpdate['iwpForecastStartDate'], errors='coerce')
# C:\Users\Ashik Kumar\AppData\Local\Temp\ipykernel_16276\1732533593.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iwpdate['iwpForecastComplete'] = pd.to_datetime(iwpdate['iwpForecastComplete'], errors='coerce')
# C:\Users\Ashik Kumar\AppData\Local\Temp\ipykernel_16276\1732533593.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iwpdate['iwpActualStartDate'] = pd.to_datetime(iwpdate['iwpActualStartDate'], errors='coerce')
# C:\Users\Ashik Kumar\AppData\Local\Temp\ipykernel_16276\1732533593.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iwpdate['iwpActualComplete'] = pd.to_datetime(iwpdate['iwpActualComplete'], errors='coerce')

# %%
set(list(dp['iwpUom']))
# Out:
# {'%',
#  'Bar',
#  'Cu. dm',
#  'DI',
#  'KG',
#  'M2',
#  'M3',
#  'NR',
#  '\\N',
#  'cu. m',
#  'ft',
#  'kgs',
#  'km',
#  'ltr',
#  'm',
#  nan,
#  'no.',
#  'no. rn.',
#  'sq. m',
#  'ton'}

# %%
sum(list(dp['iwpToDoQuantity']))
# Out:
# 9444775.091000015

# %% [markdown]
# # Hours

# %%
df_plannedHours=iwp[['iwpPlannedHours','iwpForecastHours','iwpActualHours']]
df_plannedHours = df_plannedHours.apply(pd.to_numeric, errors='coerce')
df_plannedHours=df_plannedHours.dropna()
int(sum(list(df_plannedHours['iwpActualHours'])))/int(sum(list(df_plannedHours['iwpPlannedHours'])))
# Out:
# 0.07622822804730432

# %%
int(sum(list(df_plannedHours['iwpActualHours'])))
# Out:
# 2312333462620

# %%
int(sum(list(df_plannedHours['iwpPlannedHours'])))
# Out:
# 30334346237001

# %%
int(sum(list(df_plannedHours['iwpForecastHours'])))
# Out:
# 33434239582815

# %% [markdown]
# # productivity based on work done percentage

# %% [markdown]
# method1

# %%
dp=dp[['dailyProgressId', 'iwpId','iwpTotalQuantity', 'iwpUom', 'iwpToDoQuantity',
       'iwpDoneQuantity', 'iwpDonePercentage', 'iwpProgressDate', 'postDate']]

iwp=iwp[['id','cwpRefNo','iwpPlannedStartDate',
       'iwpPlannedComplete','iwpForecastStartDate',
       'iwpForecastComplete', 'iwpActualStartDate',
       'iwpActualComplete']]

# %%
result = dp.merge(iwp, left_on='iwpId', right_on='id', how='left')

# %%
result.columns
# Out:
# Index(['dailyProgressId', 'iwpId', 'iwpTotalQuantity', 'iwpUom',
#        'iwpToDoQuantity', 'iwpDoneQuantity', 'iwpDonePercentage',
#        'iwpProgressDate', 'postDate', 'id', 'cwpRefNo', 'iwpPlannedStartDate',
#        'iwpPlannedComplete', 'iwpForecastStartDate', 'iwpForecastComplete',
#        'iwpActualStartDate', 'iwpActualComplete'],
#       dtype='object')

# %%
result=result[['iwpId', 'iwpTotalQuantity', 'iwpUom',
       'iwpDonePercentage','iwpProgressDate','cwpRefNo', 'iwpPlannedStartDate',
       'iwpPlannedComplete', 'iwpForecastStartDate', 'iwpForecastComplete',
       'iwpActualStartDate', 'iwpActualComplete']]

# %%
result=result.dropna()
result
# Out:
#        iwpId iwpTotalQuantity iwpUom iwpDonePercentage iwpProgressDate  \
# 0         99          100.000      %               50%      2019-09-10
# 1         99          100.000      %              100%      2019-09-11
# 2         99          100.000      %              100%      2019-09-12
# 3         99          100.000      %              100%      2019-09-12
# 4          6          100.000      %               30%      2019-09-26
# ...      ...              ...    ...               ...             ...
# 12945  18975          319.000     DI  0.6269592476489%      2024-03-16
# 12946  18975          319.000     DI  4.0752351097179%      2024-03-20
# 12947  18975          319.000     DI  0.6269592476489%      2024-03-25
# 12948  18975          319.000     DI  7.5235109717868%      2024-03-27
# 12949  18975          319.000     DI  5.6426332288401%      2024-03-28
#
#                           cwpRefNo iwpPlannedStartDate iwpPlannedComplete  \
# 0       CW-A01-WP2.2-010-FI-LC-102          2019-09-11         2019-09-21
# 1       CW-A01-WP2.2-010-FI-LC-102          2019-09-11         2019-09-21
# 2       CW-A01-WP2.2-010-FI-LC-102          2019-09-11         2019-09-21
# 3       CW-A01-WP2.2-010-FI-LC-102          2019-09-11         2019-09-21
# 4       CW-A01-WP2.2-010-FI-LC-102          2019-09-23         2019-10-08
# ...                            ...                 ...                ...
# 12945  CWP-A10-WP5.4-010-UG-MC-101          2024-01-07         2024-01-10
# 12946  CWP-A10-WP5.4-010-UG-MC-101          2024-01-07         2024-01-10
# 12947  CWP-A10-WP5.4-010-UG-MC-101          2024-01-07         2024-01-10
# 12948  CWP-A10-WP5.4-010-UG-MC-101          2024-01-07         2024-01-10
# 12949  CWP-A10-WP5.4-010-UG-MC-101          2024-01-07         2024-01-10
#
#       iwpForecastStartDate iwpForecastComplete iwpActualStartDate  \
# 0               2019-08-26          2019-09-21         2019-09-12
# 1               2019-08-26          2019-09-21         2019-09-12
# 2               2019-08-26          2019-09-21         2019-09-12
# 3               2019-08-26          2019-09-21         2019-09-12
# 4               2019-09-23          2019-10-08         2019-09-29
# ...                    ...                 ...                ...
# 12945           2024-01-07          2024-01-08         2024-01-09
# 12946           2024-01-07          2024-01-08         2024-01-09
# 12947           2024-01-07          2024-01-08         2024-01-09
# 12948           2024-01-07          2024-01-08         2024-01-09
# 12949           2024-01-07          2024-01-08         2024-01-09
#
#       iwpActualComplete
# 0                    \N
# 1                    \N
# 2                    \N
# 3                    \N
# 4                    \N
# ...                 ...
# 12945        0000-00-00
# 12946        0000-00-00
# 12947        0000-00-00
# 12948        0000-00-00
# 12949        0000-00-00
#
# [12891 rows x 12 columns]

# %%
result['iwpDonePercentage'] = result['iwpDonePercentage'].replace('%', '', regex=True)
result
# Out:
#        iwpId iwpTotalQuantity iwpUom iwpDonePercentage iwpProgressDate  \
# 0         99          100.000      %                50      2019-09-10
# 1         99          100.000      %               100      2019-09-11
# 2         99          100.000      %               100      2019-09-12
# 3         99          100.000      %               100      2019-09-12
# 4          6          100.000      %                30      2019-09-26
# ...      ...              ...    ...               ...             ...
# 12945  18975          319.000     DI   0.6269592476489      2024-03-16
# 12946  18975          319.000     DI   4.0752351097179      2024-03-20
# 12947  18975          319.000     DI   0.6269592476489      2024-03-25
# 12948  18975          319.000     DI   7.5235109717868      2024-03-27
# 12949  18975          319.000     DI   5.6426332288401      2024-03-28
#
#                           cwpRefNo iwpPlannedStartDate iwpPlannedComplete  \
# 0       CW-A01-WP2.2-010-FI-LC-102          2019-09-11         2019-09-21
# 1       CW-A01-WP2.2-010-FI-LC-102          2019-09-11         2019-09-21
# 2       CW-A01-WP2.2-010-FI-LC-102          2019-09-11         2019-09-21
# 3       CW-A01-WP2.2-010-FI-LC-102          2019-09-11         2019-09-21
# 4       CW-A01-WP2.2-010-FI-LC-102          2019-09-23         2019-10-08
# ...                            ...                 ...                ...
# 12945  CWP-A10-WP5.4-010-UG-MC-101          2024-01-07         2024-01-10
# 12946  CWP-A10-WP5.4-010-UG-MC-101          2024-01-07         2024-01-10
# 12947  CWP-A10-WP5.4-010-UG-MC-101          2024-01-07         2024-01-10
# 12948  CWP-A10-WP5.4-010-UG-MC-101          2024-01-07         2024-01-10
# 12949  CWP-A10-WP5.4-010-UG-MC-101          2024-01-07         2024-01-10
#
#       iwpForecastStartDate iwpForecastComplete iwpActualStartDate  \
# 0               2019-08-26          2019-09-21         2019-09-12
# 1               2019-08-26          2019-09-21         2019-09-12
# 2               2019-08-26          2019-09-21         2019-09-12
# 3               2019-08-26          2019-09-21         2019-09-12
# 4               2019-09-23          2019-10-08         2019-09-29
# ...                    ...                 ...                ...
# 12945           2024-01-07          2024-01-08         2024-01-09
# 12946           2024-01-07          2024-01-08         2024-01-09
# 12947           2024-01-07          2024-01-08         2024-01-09
# 12948           2024-01-07          2024-01-08         2024-01-09
# 12949           2024-01-07          2024-01-08         2024-01-09
#
#       iwpActualComplete
# 0                    \N
# 1                    \N
# 2                    \N
# 3                    \N
# 4                    \N
# ...                 ...
# 12945        0000-00-00
# 12946        0000-00-00
# 12947        0000-00-00
# 12948        0000-00-00
# 12949        0000-00-00
#
# [12891 rows x 12 columns]

# %%
result.replace(r'\\N', np.nan, regex=True, inplace=True)

# Drop rows with any NaN values
result = result.dropna()


result['iwpDonePercentage'] = pd.to_numeric(result['iwpDonePercentage'], errors='coerce')
# Replace inf and -inf with NaN
result['iwpDonePercentage'].replace([np.inf, -np.inf], np.nan, inplace=True)

# Optionally, handle NaNs by filling them or dropping them
result['iwpDonePercentage']= result['iwpDonePercentage'].fillna(0)
result['iwpDonePercentage'] = result['iwpDonePercentage'].astype(int)
# Out:
# C:\Users\Ashik Kumar\AppData\Local\Temp\ipykernel_16276\2165824576.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['iwpDonePercentage'] = pd.to_numeric(result['iwpDonePercentage'], errors='coerce')
# C:\Users\Ashik Kumar\AppData\Local\Temp\ipykernel_16276\2165824576.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['iwpDonePercentage'].replace([np.inf, -np.inf], np.nan, inplace=True)
# C:\Users\Ashik Kumar\AppData\Local\Temp\ipykernel_16276\2165824576.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['iwpDonePercentage']= result['iwpDonePercentage'].fillna(0)
# C:\Users\Ashik Kumar\AppData\Local\Temp\ipykernel_16276\2165824576.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['iwpDonePercentage'] = result['iwpDonePercentage'].astype(int)

# %%
result['iwpTotalQuantity'] = pd.to_numeric(result['iwpTotalQuantity'])

result_df = result.groupby('iwpId').agg(
    total_finishing_percentage=('iwpDonePercentage', 'sum'),
#     iwpPlannedStartDate=('iwpPlannedStartDate', 'min'),
#     iwpPlannedComplete=('iwpPlannedComplete', 'max'),
    iwpPlannedStartDate=('iwpForecastStartDate', 'min'),
    iwpPlannedComplete=('iwpForecastComplete', 'max'),
    iwpPlannedActualDate=('iwpActualStartDate', 'min'),
    iwpActualComplete=('iwpActualComplete', 'max')
    #iwpTotalQuantity=('iwpTotalQuantity', lambda x: x.sum() / len(x))
).reset_index()
# Out:
# C:\Users\Ashik Kumar\AppData\Local\Temp\ipykernel_16276\3022064456.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['iwpTotalQuantity'] = pd.to_numeric(result['iwpTotalQuantity'])

# %%
result_df.loc[result_df['total_finishing_percentage'] >= 100, 'total_finishing_percentage'] = 100
result_df
# Out:
#       iwpId  total_finishing_percentage iwpPlannedStartDate  \
# 0       178                         100          2021-09-20
# 1       182                          21          2021-10-15
# 2       185                          22          2021-10-27
# 3       188                          10          2021-11-25
# 4       239                          90          2022-02-15
# ...     ...                         ...                 ...
# 2160  19104                          98          2024-07-10
# 2161  19107                         100          2024-05-21
# 2162  19111                          22          2024-06-08
# 2163  19112                          81          2024-06-07
# 2164  19113                          52          2024-06-10
#
#      iwpPlannedComplete iwpPlannedActualDate iwpActualComplete
# 0            2021-09-20           0000-00-00        0000-00-00
# 1            2021-10-15           2022-06-30        0000-00-00
# 2            0000-00-00           0000-00-00        0000-00-00
# 3            2022-11-25           2021-11-25        2021-11-01
# 4            2022-02-16           2022-02-17        2022-03-23
# ...                 ...                  ...               ...
# 2160         2024-07-11           2024-07-10        2024-07-17
# 2161         2024-05-22           2024-05-21        2024-07-19
# 2162         2024-06-09           2024-06-08        2024-07-25
# 2163         2024-06-08           2024-06-07        2024-07-25
# 2164         2024-06-11           2024-06-10        2024-07-25
#
# [2165 rows x 6 columns]

# %%
# Convert date columns to datetime, handling errors
result_df['iwpPlannedStartDate'] = pd.to_datetime(result_df['iwpPlannedStartDate'], errors='coerce')
result_df['iwpPlannedComplete'] = pd.to_datetime(result_df['iwpPlannedComplete'], errors='coerce')
result_df['iwpPlannedActualDate'] = pd.to_datetime(result_df['iwpPlannedActualDate'], errors='coerce')
result_df['iwpActualComplete'] = pd.to_datetime(result_df['iwpActualComplete'], errors='coerce')

# Calculate durations
result_df['planned_duration'] = result_df['iwpPlannedComplete'] - result_df['iwpPlannedStartDate']
result_df['actual_duration'] = result_df['iwpActualComplete'] - result_df['iwpPlannedActualDate']
result_df = result_df.dropna()
result_df
# Out:
#       iwpId  total_finishing_percentage iwpPlannedStartDate  \
# 3       188                          10          2021-11-25
# 4       239                          90          2022-02-15
# 5       240                          92          2022-02-21
# 6       241                          86          2022-02-23
# 7       247                          83          2022-12-12
# ...     ...                         ...                 ...
# 2160  19104                          98          2024-07-10
# 2161  19107                         100          2024-05-21
# 2162  19111                          22          2024-06-08
# 2163  19112                          81          2024-06-07
# 2164  19113                          52          2024-06-10
#
#      iwpPlannedComplete iwpPlannedActualDate iwpActualComplete  \
# 3            2022-11-25           2021-11-25        2021-11-01
# 4            2022-02-16           2022-02-17        2022-03-23
# 5            2022-02-23           2022-03-01        2022-04-11
# 6            2022-04-11           2022-03-07        2022-09-29
# 7            2023-02-13           2022-11-24        2022-11-29
# ...                 ...                  ...               ...
# 2160         2024-07-11           2024-07-10        2024-07-17
# 2161         2024-05-22           2024-05-21        2024-07-19
# 2162         2024-06-09           2024-06-08        2024-07-25
# 2163         2024-06-08           2024-06-07        2024-07-25
# 2164         2024-06-11           2024-06-10        2024-07-25
#
#      planned_duration actual_duration
# 3            365 days        -24 days
# 4              1 days         34 days
# 5              2 days         41 days
# 6             47 days        206 days
# 7             63 days          5 days
# ...               ...             ...
# 2160           1 days          7 days
# 2161           1 days         59 days
# 2162           1 days         47 days
# 2163           1 days         48 days
# 2164           1 days         45 days
#
# [2031 rows x 8 columns]

# %%
completed_df = result_df[result_df['total_finishing_percentage'] == 100]
inprogress_df = result_df[result_df['total_finishing_percentage'] < 100]

# %%
completed_df
# Out:
#       iwpId  total_finishing_percentage iwpPlannedStartDate  \
# 11      256                         100          2024-03-05
# 18      287                         100          2022-07-17
# 24      293                         100          2022-06-11
# 44      428                         100          2022-11-17
# 45      538                         100          2022-11-21
# ...     ...                         ...                 ...
# 2063  18362                         100          2023-11-09
# 2066  18376                         100          2024-02-05
# 2088  18579                         100          2024-02-28
# 2099  18629                         100          2024-06-10
# 2161  19107                         100          2024-05-21
#
#      iwpPlannedComplete iwpPlannedActualDate iwpActualComplete  \
# 11           2024-03-06           2024-03-05        2024-03-22
# 18           2022-07-23           2022-04-07        2022-04-12
# 24           2022-06-16           2022-04-11        2022-04-16
# 44           2022-11-22           2022-11-12        2022-11-17
# 45           2022-11-26           2022-11-20        2022-11-25
# ...                 ...                  ...               ...
# 2063         2023-11-11           2023-11-09        2024-02-19
# 2066         2024-02-06           2024-01-15        2024-02-21
# 2088         2024-02-29           2024-02-28        2024-03-08
# 2099         2024-06-11           2024-06-10        2024-07-13
# 2161         2024-05-22           2024-05-21        2024-07-19
#
#      planned_duration actual_duration
# 11             1 days         17 days
# 18             6 days          5 days
# 24             5 days          5 days
# 44             5 days          5 days
# 45             5 days          5 days
# ...               ...             ...
# 2063           2 days        102 days
# 2066           1 days         37 days
# 2088           1 days          9 days
# 2099           1 days         33 days
# 2161           1 days         59 days
#
# [494 rows x 8 columns]

# %%
completed_df=completed_df[['planned_duration','actual_duration']]
# Drop rows with any NaT values
completed_df = completed_df.dropna()

# Sum all days in planned_duration and actual_duration
total_planned_duration = completed_df['planned_duration'].sum()
total_actual_duration = completed_df['actual_duration'].sum()

# Extract the total number of days from the resulting timedelta
total_planned_days = total_planned_duration.days
total_actual_days = total_actual_duration.days

# %%
total_planned_days
# Out:
# 8400

# %%
total_actual_days
# Out:
# 8297

# %%
round((total_planned_days/total_actual_days)*100 ,2)
# Out:
# 101.24

# %%
inprogress_df
# Out:
#       iwpId  total_finishing_percentage iwpPlannedStartDate  \
# 3       188                          10          2021-11-25
# 4       239                          90          2022-02-15
# 5       240                          92          2022-02-21
# 6       241                          86          2022-02-23
# 7       247                          83          2022-12-12
# ...     ...                         ...                 ...
# 2159  19093                          49          2024-07-01
# 2160  19104                          98          2024-07-10
# 2162  19111                          22          2024-06-08
# 2163  19112                          81          2024-06-07
# 2164  19113                          52          2024-06-10
#
#      iwpPlannedComplete iwpPlannedActualDate iwpActualComplete  \
# 3            2022-11-25           2021-11-25        2021-11-01
# 4            2022-02-16           2022-02-17        2022-03-23
# 5            2022-02-23           2022-03-01        2022-04-11
# 6            2022-04-11           2022-03-07        2022-09-29
# 7            2023-02-13           2022-11-24        2022-11-29
# ...                 ...                  ...               ...
# 2159         2024-07-02           2024-07-01        2024-07-12
# 2160         2024-07-11           2024-07-10        2024-07-17
# 2162         2024-06-09           2024-06-08        2024-07-25
# 2163         2024-06-08           2024-06-07        2024-07-25
# 2164         2024-06-11           2024-06-10        2024-07-25
#
#      planned_duration actual_duration
# 3            365 days        -24 days
# 4              1 days         34 days
# 5              2 days         41 days
# 6             47 days        206 days
# 7             63 days          5 days
# ...               ...             ...
# 2159           1 days         11 days
# 2160           1 days          7 days
# 2162           1 days         47 days
# 2163           1 days         48 days
# 2164           1 days         45 days
#
# [1537 rows x 8 columns]

# %%
inprogress_df['planned_duration'] = inprogress_df['planned_duration'] .dt.days
# Out:
# C:\Users\Ashik Kumar\AppData\Local\Temp\ipykernel_16276\2610311658.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inprogress_df['planned_duration'] = inprogress_df['planned_duration'] .dt.days

# %%
inprogress_df['inprogress_work_days'] = ((inprogress_df['total_finishing_percentage'] * inprogress_df['planned_duration']) / 100).astype(float).astype(int)
# Out:
# C:\Users\Ashik Kumar\AppData\Local\Temp\ipykernel_16276\1351632048.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inprogress_df['inprogress_work_days'] = ((inprogress_df['total_finishing_percentage'] * inprogress_df['planned_duration']) / 100).astype(float).astype(int)

# %%
inprogress_df['actual_duration1']= inprogress_df['actual_duration'].dt.days
# Out:
# C:\Users\Ashik Kumar\AppData\Local\Temp\ipykernel_16276\4073654084.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inprogress_df['actual_duration1']= inprogress_df['actual_duration'].dt.days

# %%
inprogress_df
# Out:
#       iwpId  total_finishing_percentage iwpPlannedStartDate  \
# 3       188                          10          2021-11-25
# 4       239                          90          2022-02-15
# 5       240                          92          2022-02-21
# 6       241                          86          2022-02-23
# 7       247                          83          2022-12-12
# ...     ...                         ...                 ...
# 2159  19093                          49          2024-07-01
# 2160  19104                          98          2024-07-10
# 2162  19111                          22          2024-06-08
# 2163  19112                          81          2024-06-07
# 2164  19113                          52          2024-06-10
#
#      iwpPlannedComplete iwpPlannedActualDate iwpActualComplete  \
# 3            2022-11-25           2021-11-25        2021-11-01
# 4            2022-02-16           2022-02-17        2022-03-23
# 5            2022-02-23           2022-03-01        2022-04-11
# 6            2022-04-11           2022-03-07        2022-09-29
# 7            2023-02-13           2022-11-24        2022-11-29
# ...                 ...                  ...               ...
# 2159         2024-07-02           2024-07-01        2024-07-12
# 2160         2024-07-11           2024-07-10        2024-07-17
# 2162         2024-06-09           2024-06-08        2024-07-25
# 2163         2024-06-08           2024-06-07        2024-07-25
# 2164         2024-06-11           2024-06-10        2024-07-25
#
#       planned_duration actual_duration  inprogress_work_days  actual_duration1
# 3                  365        -24 days                    36               -24
# 4                    1         34 days                     0                34
# 5                    2         41 days                     1                41
# 6                   47        206 days                    40               206
# 7                   63          5 days                    52                 5
# ...                ...             ...                   ...               ...
# 2159                 1         11 days                     0                11
# 2160                 1          7 days                     0                 7
# 2162                 1         47 days                     0                47
# 2163                 1         48 days                     0                48
# 2164                 1         45 days                     0                45
#
# [1537 rows x 10 columns]

# %%
sum(inprogress_df['inprogress_work_days'])/sum(inprogress_df['actual_duration1'])
# Out:
# 0.6438010955597885

# %%
negative_count = (inprogress_df['actual_duration1'] < 0).sum()

# %%
negative_count
# Out:
# 4

# %% [markdown]
# # 1. At CWP level Planned, Forecast, Actual hours. Using start and complete dates.

# %%
cwp
# Out:
#         id  user_id cwa_id  discipline_id  projectId  phaseId  cwpUnit  \
# 0     1592      166     \N             97          1        3      174
# 1     1593        1     \N             97          1        3      174
# 2     1594        1     \N              5          1        3      174
# 3     1595        1     \N              5          1        3      174
# 4     1596        1     \N              5          1        2      151
# ...    ...      ...    ...            ...        ...      ...      ...
# 1880  4192      200     \N            384         54        2      179
# 1881  4193      200     \N            384         54        6      187
# 1882  4194      200     \N            384         54        3      181
# 1883  4195      200     \N            384         54       11      214
# 1884  4196      200     \N            399         54       10      210
#
#       ewpRefId                      ewpRefNo  \
# 0            0           EW-A12-1X11-B-FI-CV
# 1         1812           EW-A11-1X11-C-FI-CV
# 2         1813           EW-A12-1X11-D-FI-PI
# 3         1814           EW-A11-1X11-E-FI-PI
# 4         1872    EW-A01-WP2.2-010-GN-MC-300
# ...        ...                           ...
# 1880      3975  EWP-A02-WP2.10-999-FI-LC-101
# 1881      3976  EWP-A05-WP4.11-999-FI-LC-101
# 1882      3977   EWP-A11-WP8.1-999-FI-LC-101
# 1883      3978   EWP-Z02-WP0.0-999-FI-LC-101
# 1884      3979   EWP-C09-WP6.2-000-FI-MC-102
#
#                                                  cwa  ...    contractorDcn  \
# 0                                                A12  ...               \N
# 1                                                A11  ...               \N
# 2                                                A12  ...               \N
# 3                                                A11  ...               \N
# 4                                      A01-WP2.2-010  ...               \N
# ...                                              ...  ...              ...
# 1880                               CLU - Common Area  ...  LG00-ZX-E-71649
# 1881                 Common Area Utility Systems -AG  ...  LG00-ZX-E-71647
# 1882  Additional Condensate Handling Facilities - AG  ...  LG00-ZX-E-71650
# 1883                        BF - Overall Common Area  ...               \N
# 1884                LNG Loading Facilities (topside)  ...               \N
#
#      revisionDescription blockchainWorkBlockId blockchain_status linked_area  \
# 0                     \N                    \N                \N          \N
# 1                     \N                    \N                \N          \N
# 2                     \N                    \N                \N          \N
# 3                     \N                    \N                \N          \N
# 4                     \N                    \N                \N          \N
# ...                  ...                   ...               ...         ...
# 1880                  \N                    \N                \N          \N
# 1881                  \N                    \N                \N          \N
# 1882                  \N                    \N                \N          \N
# 1883                  \N                    \N                \N          \N
# 1884                  \N                    \N                \N          \N
#
#      reject_remark pc_ForecastComplete_Quaterly  \
# 0               \N                   0000-00-00
# 1               \N                   0000-00-00
# 2               \N                   0000-00-00
# 3               \N                   0000-00-00
# 4               \N                   0000-00-00
# ...            ...                          ...
# 1880            \N                   0000-00-00
# 1881            \N                   0000-00-00
# 1882            \N                   0000-00-00
# 1883            \N                   0000-00-00
# 1884            \N                   0000-00-00
#
#       pc_ForecastStart_Quaterly_Exe pc_ForecastFinish_Quaterly_Exe  \
# 0                        0000-00-00                     0000-00-00
# 1                        0000-00-00                     0000-00-00
# 2                        0000-00-00                     0000-00-00
# 3                        0000-00-00                     0000-00-00
# 4                        0000-00-00                     0000-00-00
# ...                             ...                            ...
# 1880                     0000-00-00                     0000-00-00
# 1881                     0000-00-00                     0000-00-00
# 1882                     0000-00-00                     0000-00-00
# 1883                     0000-00-00                     0000-00-00
# 1884                     0000-00-00                     0000-00-00
#
#      releaseBlockchainStatus
# 0                         \N
# 1                         \N
# 2                         \N
# 3                         \N
# 4                         \N
# ...                      ...
# 1880                      \N
# 1881                      \N
# 1882                      \N
# 1883                      \N
# 1884                      \N
#
# [1885 rows x 96 columns]

# %%
cwp.columns
# Out:
# Index(['id', 'user_id', 'cwa_id', 'discipline_id', 'projectId', 'phaseId',
#        'cwpUnit', 'ewpRefId', 'ewpRefNo', 'cwa', 'cwpSubArea', 'cwpLevel',
#        'cwpType', 'cwpIcsu', 'cwpTitle', 'cwpDescription', 'cwpNo',
#        'cwpRevision', 'cwpDocumentContNo', 'cwpPlannedRelease',
#        'cwpPlannedComplete', 'cwpPlannedHours', 'cwpForecastRelease',
#        'cwpForecastComplete', 'cwpForecastHours', 'cwpActualRelease',
#        'cwpActualComplete', 'cwpActualHours', 'cwpLink', 'cwpWorkOwners',
#        'cwpWorkReleaseDate', 'cwpWorkConstruction', 'cwpWorkConstructionDate',
#        'cwpCompleteOwners', 'cwpCompleteReleaseDate',
#        'cwpCompleteConstruction', 'cwpCompleteConstructionDate', 'in_schedule',
#        'status', 'current_status', 'addDate', 'cwpPlannedReleaseExe',
#        'cwpPlannedCompleteExe', 'cwpPlannedHoursExe', 'cwpActualReleaseExe',
#        'cwpActualCompleteExe', 'cwpActualHoursExe', 'cwpForecastReleaseExe',
#        'cwpForecastCompleteExe', 'cwpForecastHoursExe', 'cwpCompilerPath',
#        'manualOrSystemStart', 'manualOrSystemComplete', 'my_selection',
#        'my_packages', 'import', 'wbsShortCode', 'contractorId',
#        'delayDuration', 'cwpSupervisor', 'auditUserid', 'auditDate',
#        'releaseConsSupApprovalStatus', 'releaseConsSup', 'releaseConsSupDate',
#        'releaseConsSupRemarks', 'compiledById', 'checkedById', 'approvedById',
#        'cwpReleaseStatus', 'releaseLead', 'releaseLeadDate',
#        'releaseLeadRemarks', 'releaseEngMgr', 'releaseEngMgrDate',
#        'releaseEngMgrRemarks', 'cwpManager', 'cwpLead', 'releaseConstMgr',
#        'releaseConstMgrDate', 'releaseConstMgrRemarks',
#        'releaseConstMgrApprovalStatus', 'releaseHold', 'cwpReleaseHold',
#        'cwpReleaseRisks', 'cwpReleaseMitigationPlan', 'contractorDcn',
#        'revisionDescription', 'blockchainWorkBlockId', 'blockchain_status',
#        'linked_area', 'reject_remark', 'pc_ForecastComplete_Quaterly',
#        'pc_ForecastStart_Quaterly_Exe', 'pc_ForecastFinish_Quaterly_Exe',
#        'releaseBlockchainStatus'],
#       dtype='object')

# %%
man_hour_cwp=cwp[['cwpNo','cwpPlannedHours','cwpForecastHours','cwpActualHours']]
man_hour_cwp
# Out:
#                              cwpNo  cwpPlannedHours  cwpForecastHours  \
# 0              CW-A12-1X11-B-FI-CV                0                 0
# 1              CW-A11-1X11-C-FI-CV                0                 0
# 2              CW-A12-1X11-D-FI-PI                0                 0
# 3              CW-A11-1X11-E-FI-PI                0                 0
# 4       CW-A01-WP2.2-010-GN-MC-300                0                 0
# ...                            ...              ...               ...
# 1880  CWP-A02-WP2.10-999-FI-LC-101                0                 0
# 1881  CWP-A05-WP4.11-999-FI-LC-101                0                 0
# 1882   CWP-A11-WP8.1-999-FI-LC-101                0                 0
# 1883   CWP-Z02-WP0.0-999-FI-LC-101                0                 0
# 1884   CWP-C09-WP6.2-000-FI-MC-102                0                 0
#
#       cwpActualHours
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 1880               0
# 1881               0
# 1882               0
# 1883               0
# 1884               0
#
# [1885 rows x 4 columns]

# %%
# Ensure the hours columns are numeric
man_hour_cwp['cwpPlannedHours'] = pd.to_numeric(man_hour_cwp['cwpPlannedHours'], errors='coerce')
man_hour_cwp['cwpForecastHours'] = pd.to_numeric(man_hour_cwp['cwpForecastHours'], errors='coerce')
man_hour_cwp['cwpActualHours'] = pd.to_numeric(man_hour_cwp['cwpActualHours'], errors='coerce')

# Drop rows with 0 or negative values in the specified columns
man_hour_cwp = man_hour_cwp[
    (man_hour_cwp['cwpPlannedHours'] > 0) &
    (man_hour_cwp['cwpForecastHours'] > 0) &
    (man_hour_cwp['cwpActualHours'] > 0)
]
# Out:
# C:\Users\Ashik Kumar\AppData\Local\Temp\ipykernel_16276\3593905575.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   man_hour_cwp['cwpPlannedHours'] = pd.to_numeric(man_hour_cwp['cwpPlannedHours'], errors='coerce')
# C:\Users\Ashik Kumar\AppData\Local\Temp\ipykernel_16276\3593905575.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   man_hour_cwp['cwpForecastHours'] = pd.to_numeric(man_hour_cwp['cwpForecastHours'], errors='coerce')
# C:\Users\Ashik Kumar\AppData\Local\Temp\ipykernel_16276\3593905575.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   man_hour_cwp['cwpActualHours'] = pd.to_numeric(man_hour_cwp['cwpActualHours'], errors='coerce')

# %%
man_hour_cwp
# Out:
#                             cwpNo  cwpPlannedHours  cwpForecastHours  \
# 1012           cwp-11-jan-2022-wp               11                11
# 1017              testing for SSO               11                11
# 1223              CWP-029-0222-01        234567893        4567890003
# 1782                    CWP-WK-01               46                66
# 1797                   cwplive123                7                 7
# 1798                   cwplive100                3                 3
# 1799                   cwplive101               10                10
# 1802                        cwp99                5                 2
# 1804               CWP-GIS-API-01                1                 2
# 1862  CWP-SANITY-LIVE-08082023-01               14                12
# 1869         CWP-LIVEMAIL-TEST-01                4                 4
# 1870     CWP-MAIL-WITHPOUTHOLD-01               10                10
# 1875                    CWY-27-02               78                90
#
#       cwpActualHours
# 1012              11
# 1017              11
# 1223       345678883
# 1782              99
# 1797               7
# 1798               3
# 1799              10
# 1802               4
# 1804               3
# 1862              21
# 1869               5
# 1870              10
# 1875              90

# %%
cwp=cwp[['cwpNo','discipline_id','cwpPlannedRelease','cwpPlannedComplete','cwpForecastRelease','cwpForecastComplete','cwpActualRelease','cwpActualComplete']]
# Convert the relevant columns to datetime, invalid parsing will be set as NaT
cwp['cwpPlannedRelease'] = pd.to_datetime(cwp['cwpPlannedRelease'], format='%Y-%m-%d', errors='coerce')
cwp['cwpPlannedComplete'] = pd.to_datetime(cwp['cwpPlannedComplete'], format='%Y-%m-%d', errors='coerce')
cwp['cwpForecastRelease'] = pd.to_datetime(cwp['cwpForecastRelease'], format='%Y-%m-%d', errors='coerce')
cwp['cwpForecastComplete'] = pd.to_datetime(cwp['cwpForecastComplete'], format='%Y-%m-%d', errors='coerce')
cwp['cwpActualRelease'] = pd.to_datetime(cwp['cwpActualRelease'], format='%Y-%m-%d', errors='coerce')
cwp['cwpActualComplete'] = pd.to_datetime(cwp['cwpActualComplete'], format='%Y-%m-%d', errors='coerce')

cwp = cwp.dropna(subset=['cwpPlannedRelease','cwpPlannedComplete','cwpForecastRelease','cwpForecastComplete','cwpActualRelease','cwpActualComplete'])
cwp
# Out:
# C:\Users\Ashik Kumar\AppData\Local\Temp\ipykernel_16276\1118026299.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cwp['cwpPlannedRelease'] = pd.to_datetime(cwp['cwpPlannedRelease'], format='%Y-%m-%d', errors='coerce')
# C:\Users\Ashik Kumar\AppData\Local\Temp\ipykernel_16276\1118026299.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cwp['cwpPlannedComplete'] = pd.to_datetime(cwp['cwpPlannedComplete'], format='%Y-%m-%d', errors='coerce')
# C:\Users\Ashik Kumar\AppData\Local\Temp\ipykernel_16276\1118026299.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cwp['cwpForecastRelease'] = pd.to_datetime(cwp['cwpForecastRelease'], format='%Y-%m-%d', errors='coerce')
# C:\Users\Ashik Kumar\AppData\Local\Temp\ipykernel_16276\1118026299.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cwp['cwpForecastComplete'] = pd.to_datetime(cwp['cwpForecastComplete'], format='%Y-%m-%d', errors='coerce')
# C:\Users\Ashik Kumar\AppData\Local\Temp\ipykernel_16276\1118026299.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cwp['cwpActualRelease'] = pd.to_datetime(cwp['cwpActualRelease'], format='%Y-%m-%d', errors='coerce')
# C:\Users\Ashik Kumar\AppData\Local\Temp\ipykernel_16276\1118026299.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cwp['cwpActualComplete'] = pd.to_datetime(cwp['cwpActualComplete'], format='%Y-%m-%d', errors='coerce')
#                             cwpNo  discipline_id cwpPlannedRelease  \
# 30    CWP-A01-WP2.6-999-FI-LC-100            384        2023-05-30
# 33    CWP-A01-WP2.6-000-FI-ME-100            401        2023-06-10
# 34    CWP-A01-WP2.6-000-FI-ME-800            402        2023-05-19
# 35    CWP-A01-WP2.6-000-UG-LC-101            384        2022-01-19
# 36    CWP-A01-WP2.6-000-UG-LC-102            384        2023-03-31
# ...                           ...            ...               ...
# 1798                   cwplive100             97        2023-04-17
# 1799                   cwplive101             97        2023-04-17
# 1869         CWP-LIVEMAIL-TEST-01            110        2023-11-21
# 1870     CWP-MAIL-WITHPOUTHOLD-01            110        2023-11-21
# 1872               CWP-TEST-18-12            110        2023-12-19
#
#      cwpPlannedComplete cwpForecastRelease cwpForecastComplete  \
# 30           2023-07-04         2024-03-16          2024-03-25
# 33           2023-08-18         2023-11-30          2023-12-15
# 34           2023-07-28         2023-07-18          2023-08-31
# 35           2023-04-22         2022-01-19          2023-04-03
# 36           2023-06-01         2023-03-31          2023-04-21
# ...                 ...                ...                 ...
# 1798         2023-04-22         2023-04-17          2023-04-22
# 1799         2023-04-22         2023-04-17          2023-04-22
# 1869         2023-11-21         2023-11-22          2023-11-24
# 1870         2023-11-21         2023-11-22          2023-11-24
# 1872         2023-12-27         2023-12-20          2023-12-29
#
#      cwpActualRelease cwpActualComplete
# 30         2024-03-15        2024-03-15
# 33         2023-11-29        2023-11-29
# 34         2023-07-19        2023-07-24
# 35         2022-01-27        2023-02-27
# 36         2023-03-30        2023-04-03
# ...               ...               ...
# 1798       2023-04-17        2023-04-22
# 1799       2023-04-17        2023-04-22
# 1869       2023-11-23        2023-11-21
# 1870       2023-11-23        2023-11-21
# 1872       2023-12-20        2023-12-18
#
# [281 rows x 8 columns]

# %%
cwp['planned_difference'] = (cwp['cwpPlannedComplete'] - cwp['cwpPlannedRelease']).dt.days
cwp['forecast_difference'] = (cwp['cwpForecastComplete'] - cwp['cwpForecastRelease']).dt.days
cwp['actual_difference'] = (cwp['cwpActualComplete'] - cwp['cwpActualRelease']).dt.days

# %%
cwp
# Out:
#                             cwpNo  discipline_id cwpPlannedRelease  \
# 30    CWP-A01-WP2.6-999-FI-LC-100            384        2023-05-30
# 33    CWP-A01-WP2.6-000-FI-ME-100            401        2023-06-10
# 34    CWP-A01-WP2.6-000-FI-ME-800            402        2023-05-19
# 35    CWP-A01-WP2.6-000-UG-LC-101            384        2022-01-19
# 36    CWP-A01-WP2.6-000-UG-LC-102            384        2023-03-31
# ...                           ...            ...               ...
# 1798                   cwplive100             97        2023-04-17
# 1799                   cwplive101             97        2023-04-17
# 1869         CWP-LIVEMAIL-TEST-01            110        2023-11-21
# 1870     CWP-MAIL-WITHPOUTHOLD-01            110        2023-11-21
# 1872               CWP-TEST-18-12            110        2023-12-19
#
#      cwpPlannedComplete cwpForecastRelease cwpForecastComplete  \
# 30           2023-07-04         2024-03-16          2024-03-25
# 33           2023-08-18         2023-11-30          2023-12-15
# 34           2023-07-28         2023-07-18          2023-08-31
# 35           2023-04-22         2022-01-19          2023-04-03
# 36           2023-06-01         2023-03-31          2023-04-21
# ...                 ...                ...                 ...
# 1798         2023-04-22         2023-04-17          2023-04-22
# 1799         2023-04-22         2023-04-17          2023-04-22
# 1869         2023-11-21         2023-11-22          2023-11-24
# 1870         2023-11-21         2023-11-22          2023-11-24
# 1872         2023-12-27         2023-12-20          2023-12-29
#
#      cwpActualRelease cwpActualComplete  planned_difference  \
# 30         2024-03-15        2024-03-15                  35
# 33         2023-11-29        2023-11-29                  69
# 34         2023-07-19        2023-07-24                  70
# 35         2022-01-27        2023-02-27                 458
# 36         2023-03-30        2023-04-03                  62
# ...               ...               ...                 ...
# 1798       2023-04-17        2023-04-22                   5
# 1799       2023-04-17        2023-04-22                   5
# 1869       2023-11-23        2023-11-21                   0
# 1870       2023-11-23        2023-11-21                   0
# 1872       2023-12-20        2023-12-18                   8
#
#       forecast_difference  actual_difference
# 30                      9                  0
# 33                     15                  0
# 34                     44                  5
# 35                    439                396
# 36                     21                  4
# ...                   ...                ...
# 1798                    5                  5
# 1799                    5                  5
# 1869                    2                 -2
# 1870                    2                 -2
# 1872                    9                 -2
#
# [281 rows x 11 columns]

# %%
cwp = cwp[
    (cwp['planned_difference'] > 0) &
    (cwp['forecast_difference'] > 0) &
    (cwp['actual_difference'] > 0)
]

cwp
# Out:
#                             cwpNo  discipline_id cwpPlannedRelease  \
# 34    CWP-A01-WP2.6-000-FI-ME-800            402        2023-05-19
# 35    CWP-A01-WP2.6-000-UG-LC-101            384        2022-01-19
# 36    CWP-A01-WP2.6-000-UG-LC-102            384        2023-03-31
# 37    CWP-A01-WP2.6-000-UG-MC-101            394        2023-03-31
# 39    CWP-A01-WP2.6-000-UG-ME-200            386        2023-07-20
# ...                           ...            ...               ...
# 1035  CWP-A08-WP7.2-420-BM-MS-101            388        2024-02-01
# 1039  CWP-A08-WP7.2-500-BM-MT-101            398        2023-12-16
# 1797                   cwplive123            110        2023-04-17
# 1798                   cwplive100             97        2023-04-17
# 1799                   cwplive101             97        2023-04-17
#
#      cwpPlannedComplete cwpForecastRelease cwpForecastComplete  \
# 34           2023-07-28         2023-07-18          2023-08-31
# 35           2023-04-22         2022-01-19          2023-04-03
# 36           2023-06-01         2023-03-31          2023-04-21
# 37           2023-06-20         2023-03-31          2023-12-22
# 39           2023-09-26         2024-01-15          2024-01-19
# ...                 ...                ...                 ...
# 1035         2024-03-27         2024-01-23          2024-10-05
# 1039         2024-01-08         2024-02-15          2024-02-29
# 1797         2023-04-22         2023-04-17          2023-04-22
# 1798         2023-04-22         2023-04-17          2023-04-22
# 1799         2023-04-22         2023-04-17          2023-04-22
#
#      cwpActualRelease cwpActualComplete  planned_difference  \
# 34         2023-07-19        2023-07-24                  70
# 35         2022-01-27        2023-02-27                 458
# 36         2023-03-30        2023-04-03                  62
# 37         2023-04-06        2023-12-20                  81
# 39         2024-01-15        2024-01-18                  68
# ...               ...               ...                 ...
# 1035       2024-06-01        2024-06-04                  55
# 1039       2024-02-28        2024-02-29                  23
# 1797       2023-04-17        2023-04-22                   5
# 1798       2023-04-17        2023-04-22                   5
# 1799       2023-04-17        2023-04-22                   5
#
#       forecast_difference  actual_difference
# 34                     44                  5
# 35                    439                396
# 36                     21                  4
# 37                    266                258
# 39                      4                  3
# ...                   ...                ...
# 1035                  256                  3
# 1039                   14                  1
# 1797                    5                  5
# 1798                    5                  5
# 1799                    5                  5
#
# [191 rows x 11 columns]

# %%
print("Total_planned_days_for_cwp", sum(list(cwp['planned_difference'])))
print("Total_forecast_days_for_cwp", sum(list(cwp['forecast_difference'])))
print("Total_actual_days_for_cwp", sum(list(cwp['actual_difference'])))
# Out:
# Total_planned_days_for_cwp 16466
# Total_forecast_days_for_cwp 21204
# Total_actual_days_for_cwp 8369

# %% [markdown]
# # 2. % Saved manhours. (Difference in forecast and actual) /forecast

# %%
#if we are taking 10 hrs per day
Total_planned_hrs_for_cwp=sum(list(cwp['planned_difference'])) *10
Total_forecast_hrs_for_cwp=sum(list(cwp['forecast_difference']))*10
Total_actual_hrs_for_cwp=sum(list(cwp['actual_difference']))*10

# %%
round((Total_forecast_hrs_for_cwp-Total_actual_hrs_for_cwp)/Total_forecast_hrs_for_cwp,2)
# Out:
# 0.61

# %% [markdown]
# # 3.Performance efficiency  = Forecast hours/ actual hours

# %%
round(Total_forecast_hrs_for_cwp/Total_actual_hrs_for_cwp ,2)
# Out:
# 2.53

# %% [markdown]
# # 4. Performance efficiency vs discipline id – plot.

# %%
cwp_pe=cwp[['discipline_id','forecast_difference','actual_difference']]
cwp_pe
# Out:
#       discipline_id  forecast_difference  actual_difference
# 34              402                   44                  5
# 35              384                  439                396
# 36              384                   21                  4
# 37              394                  266                258
# 39              386                    4                  3
# ...             ...                  ...                ...
# 1035            388                  256                  3
# 1039            398                   14                  1
# 1797            110                    5                  5
# 1798             97                    5                  5
# 1799             97                    5                  5
#
# [191 rows x 3 columns]

# %%
grouped_df = cwp_pe.groupby('discipline_id').agg({
    'forecast_difference': 'sum',
    'actual_difference': 'sum'
}).reset_index()

grouped_df['forecast_hours']=grouped_df['forecast_difference']*10
grouped_df['actual_hours']=grouped_df['actual_difference']*10
grouped_df
# Out:
#     discipline_id  forecast_difference  actual_difference  forecast_hours  \
# 0              97                   11                 18             110
# 1             110                    5                  5              50
# 2             384                 7755               2941           77550
# 3             386                  596                100            5960
# 4             388                 1809                 29           18090
# 5             392                  912                738            9120
# 6             394                 1420               2518           14200
# 7             398                   70                  5             700
# 8             399                  875                764            8750
# 9             400                 2291                206           22910
# 10            401                 2353                258           23530
# 11            402                 3107                787           31070
#
#     actual_hours
# 0            180
# 1             50
# 2          29410
# 3           1000
# 4            290
# 5           7380
# 6          25180
# 7             50
# 8           7640
# 9           2060
# 10          2580
# 11          7870

# %%
grouped_df['performace_efficiency']=round(grouped_df['forecast_hours']/grouped_df['actual_hours'] ,2)
grouped_df
# Out:
#     discipline_id  forecast_difference  actual_difference  forecast_hours  \
# 0              97                   11                 18             110
# 1             110                    5                  5              50
# 2             384                 7755               2941           77550
# 3             386                  596                100            5960
# 4             388                 1809                 29           18090
# 5             392                  912                738            9120
# 6             394                 1420               2518           14200
# 7             398                   70                  5             700
# 8             399                  875                764            8750
# 9             400                 2291                206           22910
# 10            401                 2353                258           23530
# 11            402                 3107                787           31070
#
#     actual_hours  performace_efficiency
# 0            180                   0.61
# 1             50                   1.00
# 2          29410                   2.64
# 3           1000                   5.96
# 4            290                  62.38
# 5           7380                   1.24
# 6          25180                   0.56
# 7             50                  14.00
# 8           7640                   1.15
# 9           2060                  11.12
# 10          2580                   9.12
# 11          7870                   3.95

# %%
dis = pd.read_csv('pace_workmanagement_discipline11.csv')
dis=dis[['disciplineId','disciplineName']]
dis = dis.rename(columns={'disciplineId': 'discipline_id'})

# %%
result = pd.merge(grouped_df, dis, how='left', on='discipline_id')
result
# Out:
#     discipline_id  forecast_difference  actual_difference  forecast_hours  \
# 0              97                   11                 18             110
# 1             110                    5                  5              50
# 2             384                 7755               2941           77550
# 3             386                  596                100            5960
# 4             388                 1809                 29           18090
# 5             392                  912                738            9120
# 6             394                 1420               2518           14200
# 7             398                   70                  5             700
# 8             399                  875                764            8750
# 9             400                 2291                206           22910
# 10            401                 2353                258           23530
# 11            402                 3107                787           31070
#
#     actual_hours  performace_efficiency              disciplineName
# 0            180                   0.61                       CIVIL
# 1             50                   1.00                  ALLOWANCES
# 2          29410                   2.64               Civil-General
# 3           1000                   5.96          Electrical-General
# 4            290                  62.38     Instrumentation-General
# 5           7380                   1.24                  Mechanical
# 6          25180                   0.56                      Piping
# 7             50                  14.00                     Telecom
# 8           7640                   1.15             Civil-Structure
# 9           2060                  11.12         Electrical-Lighting
# 10          2580                   9.12            Electrical-Cable
# 11          7870                   3.95  Electrical-Earth/Grounding

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Melt the DataFrame to long format for Seaborn
df_melted = result[['disciplineName', 'forecast_hours', 'actual_hours']].melt(id_vars='disciplineName', var_name='Type', value_name='Hours')

# Plotting
plt.figure(figsize=(10, 6))
ax = sns.barplot(data=df_melted, x='disciplineName', y='Hours', hue='Type')

# Rotate and align x-axis labels
plt.xticks(rotation=45, ha='right')

# Adding titles and labels
plt.title('Forecast vs Actual Hours by Discipline Name')
plt.xlabel('Discipline Name')
plt.ylabel('Hours')

# Adding the number labels on each bar with a smaller font size
for container in ax.containers:
    ax.bar_label(container, fontsize=7)

plt.tight_layout()  # Adjust layout to make room for the rotated labels

plt.show()

# %%
# Plotting
plt.figure(figsize=(10, 6))
ax = sns.barplot(data=result[['disciplineName','performace_efficiency']], x='disciplineName', y='performace_efficiency')

# Rotate and align x-axis labels
plt.xticks(rotation=45, ha='right')

# Adding titles and labels
plt.title('Performance Efficiency by Discipline Name')
plt.xlabel('Discipline Name')
plt.ylabel('Performance Efficiency')

# Adding the number labels on each bar with a smaller font size
for container in ax.containers:
    ax.bar_label(container, fontsize=8)

plt.tight_layout()  # Adjust layout to make room for the rotated labels

plt.show()
